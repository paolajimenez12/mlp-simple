# %% [markdown]
# # Notebook: mlp_simple
#
# Sigue las instrucciones del laboratorio para entrenar un MLP con MNIST.

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import time

print('TensorFlow:', tf.__version__)
